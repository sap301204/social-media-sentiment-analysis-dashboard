# %% [markdown]
# <a href="https://colab.research.google.com/github/sap301204/social-media-sentiment-analysis-dashboard/blob/main/sentiment_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas numpy scikit-learn nltk joblib

# %%
import pandas as pd

data = {
    "text": [
        "I love this product",
        "Worst experience ever",
        "It is okay",
        "Amazing service",
        "Very bad quality",
        "Not great not bad",
        "Absolutely fantastic",
        "Terrible support",
        "I am satisfied",
        "Could be better"
    ],
    "sentiment": [
        "positive",
        "negative",
        "neutral",
        "positive",
        "negative",
        "neutral",
        "positive",
        "negative",
        "positive",
        "neutral"
    ]
}

df = pd.DataFrame(data)
df.to_csv("data.csv", index=False)

df.head()
# Out:
#                     text sentiment
# 0    I love this product  positive
# 1  Worst experience ever  negative
# 2             It is okay   neutral
# 3        Amazing service  positive
# 4       Very bad quality  negative

# %%
import re
import nltk
from nltk.corpus import stopwords

nltk.download('stopwords')

def clean_text(text):
    text = re.sub(r"http\S+|[^A-Za-z\s]", "", text)
    text = text.lower()
    text = " ".join([word for word in text.split() if word not in stopwords.words('english')])
    return text

df['cleaned'] = df['text'].apply(clean_text)
df.head()
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#                     text sentiment                cleaned
# 0    I love this product  positive           love product
# 1  Worst experience ever  negative  worst experience ever
# 2             It is okay   neutral                   okay
# 3        Amazing service  positive        amazing service
# 4       Very bad quality  negative            bad quality

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

X_train, X_test, y_train, y_test = train_test_split(
    df['cleaned'], df['sentiment'], test_size=0.2, random_state=42
)

vectorizer = TfidfVectorizer()
X_train_vec = vectorizer.fit_transform(X_train)
X_test_vec = vectorizer.transform(X_test)

model = LogisticRegression()
model.fit(X_train_vec, y_train)

y_pred = model.predict(X_test_vec)

print("Accuracy:", accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5

# %%
test_text = ["I really love this app"]
cleaned = [clean_text(t) for t in test_text]

vec = vectorizer.transform(cleaned)
prediction = model.predict(vec)

print("Prediction:", prediction[0])
# Out:
# Prediction: positive

# %%
import joblib

joblib.dump(model, "model.pkl")
joblib.dump(vectorizer, "vectorizer.pkl")
# Out:
# ['vectorizer.pkl']
